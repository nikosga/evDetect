# %%
# Libraries
# %load_ext autoreload
# %autoreload 2

import sys; sys.path.insert(0, '..')
import time
from evdetect.gen_data import Scenario
from evdetect.evdetector import Detector

# %%
s = Scenario()
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
print(d.model.summary())
d.plot()
# Out:
# Estimating on 7 cores
# {'detected': True, 'event_time': 200.0, 'event_halflife': inf, 'decay_lambda': 0.0, 'amplitude': 4.97, 'trend': 0.0, 'rsquared': 0.99}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 3.858e+04
# Date:                Fri, 01 Nov 2024   Prob (F-statistic):               0.00
# Time:                        21:43:45   Log-Likelihood:                 104.79
# No. Observations:                 500   AIC:                            -203.6
# Df Residuals:                     497   BIC:                            -190.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# event_exp_lt     4.9678      0.034    146.507      0.000       4.901       5.034
# time             0.0001      0.000      0.945      0.345      -0.000       0.000
# Intercept        0.0067      0.018      0.373      0.710      -0.029       0.042
# ==============================================================================
# Omnibus:                        5.742   Durbin-Watson:                   2.035
# Prob(Omnibus):                  0.057   Jarque-Bera (JB):                4.887
# Skew:                           0.162   Prob(JB):                       0.0869
# Kurtosis:                       2.641   Cond. No.                     1.12e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='diminishing')
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
print(d.model.summary())
d.plot()
# Out:
# Estimating on 7 cores
# {'detected': True, 'event_time': 200.0, 'event_halflife': 4.6, 'decay_lambda': 0.15000000000000002, 'amplitude': 6.4, 'trend': -0.0, 'rsquared': 0.84}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.828
# Model:                            OLS   Adj. R-squared:                  0.827
# Method:                 Least Squares   F-statistic:                     1198.
# Date:                Fri, 01 Nov 2024   Prob (F-statistic):          8.57e-191
# Time:                        21:43:48   Log-Likelihood:                -22.229
# No. Observations:                 500   AIC:                             50.46
# Df Residuals:                     497   BIC:                             63.10
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# event_exp_lt     6.4105      0.131     48.895      0.000       6.153       6.668
# time          3.184e-05   7.87e-05      0.404      0.686      -0.000       0.000
# Intercept        0.0150      0.023      0.655      0.513      -0.030       0.060
# ==============================================================================
# Omnibus:                       37.023   Durbin-Watson:                   1.295
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              144.183
# Skew:                           0.142   Prob(JB):                     4.91e-32
# Kurtosis:                       5.615   Cond. No.                     3.34e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.34e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='constant_with_trend')
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
print(d.model.summary())
d.plot()
# Out:
# Estimating on 7 cores
# {'detected': True, 'event_time': 200.0, 'event_halflife': inf, 'decay_lambda': 0.0, 'amplitude': 5.01, 'trend': 0.01, 'rsquared': 1.0}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                 9.174e+04
# Date:                Fri, 01 Nov 2024   Prob (F-statistic):               0.00
# Time:                        21:43:50   Log-Likelihood:                 107.07
# No. Observations:                 500   AIC:                            -208.1
# Df Residuals:                     497   BIC:                            -195.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# event_exp_lt     5.0162      0.034    148.609      0.000       4.950       5.083
# time             0.0100      0.000     87.043      0.000       0.010       0.010
# Intercept        0.0078      0.018      0.435      0.664      -0.028       0.043
# ==============================================================================
# Omnibus:                        0.195   Durbin-Watson:                   1.928
# Prob(Omnibus):                  0.907   Jarque-Bera (JB):                0.306
# Skew:                          -0.009   Prob(JB):                        0.858
# Kurtosis:                       2.880   Cond. No.                     1.12e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='diminishing_with_trend')
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
print(d.model.summary())
d.plot()
# Out:
# Estimating on 7 cores
# {'detected': True, 'event_time': 200.0, 'event_halflife': 2.0, 'decay_lambda': 0.35000000000000003, 'amplitude': 6.55, 'trend': 0.01, 'rsquared': 0.92}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.942
# Model:                            OLS   Adj. R-squared:                  0.942
# Method:                 Least Squares   F-statistic:                     4072.
# Date:                Fri, 01 Nov 2024   Prob (F-statistic):          6.47e-309
# Time:                        21:43:53   Log-Likelihood:                -204.48
# No. Observations:                 500   AIC:                             415.0
# Df Residuals:                     497   BIC:                             427.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# event_exp_lt     6.5890      0.261     25.256      0.000       6.076       7.102
# time             0.0099      0.000     87.490      0.000       0.010       0.010
# Intercept        0.0959      0.033      2.920      0.004       0.031       0.160
# ==============================================================================
# Omnibus:                      256.654   Durbin-Watson:                   0.658
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1923.153
# Skew:                           2.125   Prob(JB):                         0.00
# Kurtosis:                      11.617   Cond. No.                     4.62e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.62e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
