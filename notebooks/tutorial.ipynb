# %%
# Libraries
# %load_ext autoreload
# %autoreload 2

import sys; sys.path.insert(0, '..')
from ev_detect.gen_data import Scenario
from ev_detect.evdetector import Detector

# %%
s = Scenario()
s.plot()

# %%
d=Detector()
d.fit(s.data)
d.summary()
d.predict()
d.plot()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 3.843e+04
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):               0.00
# Time:                        12:06:09   Log-Likelihood:                 99.701
# No. Observations:                 500   AIC:                            -193.4
# Df Residuals:                     497   BIC:                            -180.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0541      0.018     -2.964      0.003      -0.090      -0.018
# event          5.0123      0.034    146.321      0.000       4.945       5.080
# time        9.545e-05      0.000      0.822      0.412      -0.000       0.000
# ==============================================================================
# Omnibus:                        1.313   Durbin-Watson:                   2.107
# Prob(Omnibus):                  0.519   Jarque-Bera (JB):                1.292
# Skew:                          -0.124   Prob(JB):                        0.524
# Kurtosis:                       2.978   Cond. No.                     1.12e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='diminishing')
s.plot()

# %%
d=Detector(event_type='diminishing')
d.fit(s.data)
d.summary()
d.predict()
d.plot()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.701
# Model:                            OLS   Adj. R-squared:                  0.700
# Method:                 Least Squares   F-statistic:                     581.9
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):          6.24e-131
# Time:                        12:06:41   Log-Likelihood:                -120.59
# No. Observations:                 500   AIC:                             247.2
# Df Residuals:                     497   BIC:                             259.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                              0.0798      0.028      2.866      0.004       0.025       0.134
# event:np.exp(-l * time_from_event)     6.1044      0.179     34.036      0.000       5.752       6.457
# time                               -7.367e-05   9.58e-05     -0.769      0.442      -0.000       0.000
# ==============================================================================
# Omnibus:                      145.777   Durbin-Watson:                   0.793
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              409.138
# Skew:                           1.409   Prob(JB):                     1.44e-89
# Kurtosis:                       6.420   Cond. No.                     3.75e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.75e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='constant_with_trend')
s.plot()

# %%
d=Detector(event_type='diminishing')
d.fit(s.data)
d.summary()
d.predict()
d.plot()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                 9.013e+04
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):               0.00
# Time:                        12:07:12   Log-Likelihood:                 101.16
# No. Observations:                 500   AIC:                            -196.3
# Df Residuals:                     497   BIC:                            -183.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             -0.0332      0.018     -1.822      0.069      -0.069       0.003
# event:np.exp(-l * time_from_event)     5.0031      0.034    146.478      0.000       4.936       5.070
# time                                   0.0101      0.000     87.131      0.000       0.010       0.010
# ==============================================================================
# Omnibus:                        0.085   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.958   Jarque-Bera (JB):                0.017
# Skew:                          -0.000   Prob(JB):                        0.991
# Kurtosis:                       3.029   Cond. No.                     1.12e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='diminishing_with_trend')
s.plot()

# %%
d=Detector(event_type='diminishing')
d.fit(s.data)
d.summary()
d.predict()
d.plot()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.977
# Method:                 Least Squares   F-statistic:                 1.038e+04
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):               0.00
# Time:                        12:07:44   Log-Likelihood:                 26.707
# No. Observations:                 500   AIC:                            -47.41
# Df Residuals:                     497   BIC:                            -34.77
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                              0.0243      0.021      1.170      0.242      -0.017       0.065
# event:np.exp(-l * time_from_event)     5.3696      0.119     45.167      0.000       5.136       5.603
# time                                   0.0099   7.14e-05    138.920      0.000       0.010       0.010
# ==============================================================================
# Omnibus:                        3.813   Durbin-Watson:                   1.553
# Prob(Omnibus):                  0.149   Jarque-Bera (JB):                3.736
# Skew:                           0.212   Prob(JB):                        0.154
# Kurtosis:                       3.015   Cond. No.                     3.34e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.34e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
