# %%
# Libraries
# %load_ext autoreload
# %autoreload 2

import sys; sys.path.insert(0, '..')
from evdetect.gen_data import Scenario
from evdetect.evdetector import Detector

# %%
s = Scenario()
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
d.predict()
d.plot()
# Out:
# {'detected': True, 'optimal_results': [{'time': 200, 'coef': 4.96, 'trend': 0.0, 'pval': 0.0, 'trend_pval': 0.58, 'rsquared': 0.99, 'weighted_coef': 4.92, 'detected_event': 1}], 'event_time': np.int64(200), 'event_halflife': inf, 'decay_lambda': np.float64(0.0)}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                 3.506e+04
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):               0.00
# Time:                        22:36:10   Log-Likelihood:                 81.553
# No. Observations:                 500   AIC:                            -157.1
# Df Residuals:                     497   BIC:                            -144.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                              0.0283      0.019      1.492      0.136      -0.009       0.065
# event:np.exp(-l * time_from_event)     5.0317      0.036    141.652      0.000       4.962       5.102
# time                                  -0.0002      0.000     -1.460      0.145      -0.000    6.09e-05
# ==============================================================================
# Omnibus:                        1.107   Durbin-Watson:                   1.918
# Prob(Omnibus):                  0.575   Jarque-Bera (JB):                1.140
# Skew:                          -0.042   Prob(JB):                        0.566
# Kurtosis:                       2.782   Cond. No.                     1.12e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='diminishing')
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
d.predict()
d.plot()
# Out:
# {'detected': True, 'optimal_results': [{'time': 200, 'coef': 5.42, 'trend': 0.03, 'pval': 0.0, 'trend_pval': 0.0, 'rsquared': 0.93, 'weighted_coef': 5.06, 'detected_event': 1}], 'event_time': np.int64(200), 'event_halflife': np.float64(2.772588722239781), 'decay_lambda': np.float64(0.25)}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.654
# Model:                            OLS   Adj. R-squared:                  0.653
# Method:                 Least Squares   F-statistic:                     470.2
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):          2.45e-115
# Time:                        22:36:40   Log-Likelihood:                -150.97
# No. Observations:                 500   AIC:                             307.9
# Df Residuals:                     497   BIC:                             320.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                              0.0570      0.030      1.928      0.054      -0.001       0.115
# event:np.exp(-l * time_from_event)     6.3606      0.208     30.616      0.000       5.952       6.769
# time                               -4.766e-05      0.000     -0.468      0.640      -0.000       0.000
# ==============================================================================
# Omnibus:                       96.536   Durbin-Watson:                   0.784
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              292.294
# Skew:                           0.903   Prob(JB):                     3.38e-64
# Kurtosis:                       6.281   Cond. No.                     4.09e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.09e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='constant_with_trend')
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
d.predict()
d.plot()
# Out:
# {'detected': True, 'optimal_results': [{'time': 200, 'coef': 5.14, 'trend': 0.01, 'pval': 0.0, 'trend_pval': 0.01, 'rsquared': 1.0, 'weighted_coef': 5.12, 'detected_event': 1}], 'event_time': np.int64(200), 'event_halflife': inf, 'decay_lambda': np.float64(0.0)}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                 9.312e+04
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):               0.00
# Time:                        22:37:12   Log-Likelihood:                 110.54
# No. Observations:                 500   AIC:                            -215.1
# Df Residuals:                     497   BIC:                            -202.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             -0.0179      0.018     -1.000      0.318      -0.053       0.017
# event:np.exp(-l * time_from_event)     5.0127      0.034    149.540      0.000       4.947       5.079
# time                                   0.0100      0.000     87.893      0.000       0.010       0.010
# ==============================================================================
# Omnibus:                        1.393   Durbin-Watson:                   2.046
# Prob(Omnibus):                  0.498   Jarque-Bera (JB):                1.383
# Skew:                          -0.055   Prob(JB):                        0.501
# Kurtosis:                       2.767   Cond. No.                     1.12e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='diminishing_with_trend')
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
d.predict()
d.plot()
# Out:
# {'detected': True, 'optimal_results': [{'time': 200, 'coef': 5.91, 'trend': 0.01, 'pval': 0.0, 'trend_pval': 0.0, 'rsquared': 0.93, 'weighted_coef': 5.5, 'detected_event': 1}], 'event_time': np.int64(200), 'event_halflife': np.float64(4.620981203732968), 'decay_lambda': np.float64(0.15000000000000002)}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.976
# Model:                            OLS   Adj. R-squared:                  0.975
# Method:                 Least Squares   F-statistic:                     9907.
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):               0.00
# Time:                        22:37:43   Log-Likelihood:                 4.5847
# No. Observations:                 500   AIC:                            -3.169
# Df Residuals:                     497   BIC:                             9.475
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                              0.0156      0.022      0.716      0.474      -0.027       0.058
# event:np.exp(-l * time_from_event)     6.1501      0.124     49.494      0.000       5.906       6.394
# time                                   0.0100   7.46e-05    134.125      0.000       0.010       0.010
# ==============================================================================
# Omnibus:                       30.993   Durbin-Watson:                   1.510
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.442
# Skew:                           0.345   Prob(JB):                     3.74e-15
# Kurtosis:                       4.648   Cond. No.                     3.34e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.34e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
