# %%
# Libraries
# %load_ext autoreload
# %autoreload 2

import sys; sys.path.insert(0, '..')
import time
from evdetect.gen_data import Scenario
from evdetect.evdetector import Detector

# %%
s = Scenario()
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
print(d.model.summary())
d.plot()
# Out:
# {'detected': True, 'event_time': 200.0, 'event_halflife': inf, 'decay_lambda': 0.0, 'amplitude': 4.98, 'trend': 0.0, 'rsquared': 0.99}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                 3.806e+04
# Date:                Sat, 02 Nov 2024   Prob (F-statistic):               0.00
# Time:                        11:57:00   Log-Likelihood:                 101.82
# No. Observations:                 500   AIC:                            -197.6
# Df Residuals:                     497   BIC:                            -185.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# event_exp_lt     4.9847      0.034    146.133      0.000       4.918       5.052
# time          2.464e-05      0.000      0.213      0.831      -0.000       0.000
# Intercept        0.0105      0.018      0.580      0.562      -0.025       0.046
# ==============================================================================
# Omnibus:                        1.816   Durbin-Watson:                   1.774
# Prob(Omnibus):                  0.403   Jarque-Bera (JB):                1.609
# Skew:                          -0.122   Prob(JB):                        0.447
# Kurtosis:                       3.133   Cond. No.                     1.12e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='diminishing')
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
print(d.model.summary())
d.plot()
# Out:
# {'detected': True, 'event_time': 200.0, 'event_halflife': 3.5, 'decay_lambda': 0.2, 'amplitude': 5.89, 'trend': 0.0, 'rsquared': 0.75}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.753
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     759.0
# Date:                Sat, 02 Nov 2024   Prob (F-statistic):          8.59e-152
# Time:                        11:57:03   Log-Likelihood:                -35.210
# No. Observations:                 500   AIC:                             76.42
# Df Residuals:                     497   BIC:                             89.06
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# event_exp_lt     5.8874      0.151     38.938      0.000       5.590       6.184
# time           3.43e-05   8.08e-05      0.425      0.671      -0.000       0.000
# Intercept        0.0265      0.023      1.127      0.260      -0.020       0.073
# ==============================================================================
# Omnibus:                       39.801   Durbin-Watson:                   1.168
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.110
# Skew:                           0.444   Prob(JB):                     1.21e-19
# Kurtosis:                       4.842   Cond. No.                     3.75e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.75e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='constant_with_trend')
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
print(d.model.summary())
d.plot()
# Out:
# {'detected': True, 'event_time': 200.0, 'event_halflife': inf, 'decay_lambda': 0.0, 'amplitude': 4.94, 'trend': 0.01, 'rsquared': 1.0}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                 8.603e+04
# Date:                Sat, 02 Nov 2024   Prob (F-statistic):               0.00
# Time:                        11:57:05   Log-Likelihood:                 92.364
# No. Observations:                 500   AIC:                            -178.7
# Df Residuals:                     497   BIC:                            -166.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# event_exp_lt     4.9395      0.035    142.097      0.000       4.871       5.008
# time             0.0102      0.000     86.182      0.000       0.010       0.010
# Intercept        0.0015      0.019      0.082      0.935      -0.035       0.038
# ==============================================================================
# Omnibus:                        3.194   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.202   Jarque-Bera (JB):                2.998
# Skew:                          -0.182   Prob(JB):                        0.223
# Kurtosis:                       3.105   Cond. No.                     1.12e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='diminishing_with_trend')
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
print(d.model.summary())
d.plot()
# Out:
# {'detected': True, 'event_time': 200.0, 'event_halflife': 2.3, 'decay_lambda': 0.30000000000000004, 'amplitude': 6.95, 'trend': 0.01, 'rsquared': 0.95}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.948
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     4510.
# Date:                Sat, 02 Nov 2024   Prob (F-statistic):          2.49e-319
# Time:                        11:57:08   Log-Likelihood:                -174.95
# No. Observations:                 500   AIC:                             355.9
# Df Residuals:                     497   BIC:                             368.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# event_exp_lt     6.9499      0.233     29.820      0.000       6.492       7.408
# time             0.0097      0.000     91.248      0.000       0.010       0.010
# Intercept        0.1085      0.031      3.502      0.001       0.048       0.169
# ==============================================================================
# Omnibus:                      267.665   Durbin-Watson:                   0.802
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4462.879
# Skew:                           1.931   Prob(JB):                         0.00
# Kurtosis:                      17.118   Cond. No.                     4.38e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.38e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
