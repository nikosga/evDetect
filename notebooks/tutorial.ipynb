# %%
# Libraries
# %load_ext autoreload
# %autoreload 2

import sys; sys.path.insert(0, '..')
import time
from evdetect.gen_data import Scenario
from evdetect.evdetector import Detector

# %%
s = Scenario()
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
d.predict()
d.plot()
# Out:
# Estimating on 7 cores
# {'detected': True, 'optimal_results': [{'time': 200, 'coef': 5.04, 'trend': -0.0, 'pval': 0.0, 'trend_pval': 0.4, 'rsquared': 0.99, 'weighted_coef': 5.0, 'detected_event': 1}], 'event_time': np.int64(200), 'event_halflife': inf, 'decay_lambda': np.float64(0.0)}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 3.946e+04
# Date:                Fri, 01 Nov 2024   Prob (F-statistic):               0.00
# Time:                        11:24:38   Log-Likelihood:                 108.76
# No. Observations:                 500   AIC:                            -211.5
# Df Residuals:                     497   BIC:                            -198.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# event_exp_lt     5.0352      0.034    149.677      0.000       4.969       5.101
# time         -9.527e-05      0.000     -0.835      0.404      -0.000       0.000
# Intercept        0.0055      0.018      0.306      0.760      -0.030       0.041
# ==============================================================================
# Omnibus:                        1.868   Durbin-Watson:                   2.075
# Prob(Omnibus):                  0.393   Jarque-Bera (JB):                1.730
# Skew:                           0.053   Prob(JB):                        0.421
# Kurtosis:                       2.732   Cond. No.                     1.12e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='diminishing')
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
d.predict()
d.plot()
# Out:
# Estimating on 7 cores
# {'detected': True, 'optimal_results': [{'time': 200, 'coef': 6.16, 'trend': -0.0, 'pval': 0.0, 'trend_pval': 0.36, 'rsquared': 0.79, 'weighted_coef': 4.88, 'detected_event': 1}], 'event_time': np.int64(200), 'event_halflife': np.float64(3.465735902799726), 'decay_lambda': np.float64(0.2)}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.784
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                     900.4
# Date:                Fri, 01 Nov 2024   Prob (F-statistic):          5.78e-166
# Time:                        11:24:40   Log-Likelihood:                -16.650
# No. Observations:                 500   AIC:                             39.30
# Df Residuals:                     497   BIC:                             51.94
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# event_exp_lt     6.1713      0.146     42.359      0.000       5.885       6.458
# time         -4.733e-05   7.78e-05     -0.608      0.543      -0.000       0.000
# Intercept        0.0554      0.023      2.451      0.015       0.011       0.100
# ==============================================================================
# Omnibus:                       64.817   Durbin-Watson:                   1.235
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              142.336
# Skew:                           0.707   Prob(JB):                     1.24e-31
# Kurtosis:                       5.199   Cond. No.                     3.75e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.75e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='constant_with_trend')
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
d.predict()
d.plot()
# Out:
# Estimating on 7 cores
# {'detected': True, 'optimal_results': [{'time': 200, 'coef': 4.98, 'trend': 0.01, 'pval': 0.0, 'trend_pval': 0.0, 'rsquared': 1.0, 'weighted_coef': 4.97, 'detected_event': 1}], 'event_time': np.int64(200), 'event_halflife': inf, 'decay_lambda': np.float64(0.0)}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                 8.561e+04
# Date:                Fri, 01 Nov 2024   Prob (F-statistic):               0.00
# Time:                        11:24:43   Log-Likelihood:                 89.127
# No. Observations:                 500   AIC:                            -172.3
# Df Residuals:                     497   BIC:                            -159.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# event_exp_lt     4.9828      0.035    142.415      0.000       4.914       5.052
# time             0.0101      0.000     85.285      0.000       0.010       0.010
# Intercept       -0.0196      0.019     -1.053      0.293      -0.056       0.017
# ==============================================================================
# Omnibus:                        0.135   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.935   Jarque-Bera (JB):                0.238
# Skew:                           0.009   Prob(JB):                        0.888
# Kurtosis:                       2.894   Cond. No.                     1.12e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='diminishing_with_trend')
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
d.predict()
d.plot()
# Out:
# Estimating on 7 cores
# {'detected': True, 'optimal_results': [{'time': 200, 'coef': 7.27, 'trend': 0.01, 'pval': 0.0, 'trend_pval': 0.0, 'rsquared': 0.92, 'weighted_coef': 6.69, 'detected_event': 1}], 'event_time': np.int64(200), 'event_halflife': np.float64(1.9804205158855577), 'decay_lambda': np.float64(0.35000000000000003)}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.940
# Model:                            OLS   Adj. R-squared:                  0.939
# Method:                 Least Squares   F-statistic:                     3865.
# Date:                Fri, 01 Nov 2024   Prob (F-statistic):          1.25e-303
# Time:                        11:24:46   Log-Likelihood:                -221.90
# No. Observations:                 500   AIC:                             449.8
# Df Residuals:                     497   BIC:                             462.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# event_exp_lt     7.3086      0.270     27.056      0.000       6.778       7.839
# time             0.0099      0.000     84.579      0.000       0.010       0.010
# Intercept        0.0874      0.034      2.570      0.010       0.021       0.154
# ==============================================================================
# Omnibus:                      248.631   Durbin-Watson:                   0.622
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2327.525
# Skew:                           1.951   Prob(JB):                         0.00
# Kurtosis:                      12.824   Cond. No.                     4.62e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.62e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
