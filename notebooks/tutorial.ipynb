# %%
# Libraries
# %load_ext autoreload
# %autoreload 2

import sys; sys.path.insert(0, '..')
from ev_detect.gen_data import Scenario
from ev_detect.evdetector import Detector

# %%
s = Scenario()
s.plot()

# %%
d=Detector()
d.fit(s.data)
d.summary()
d.predict()
d.plot()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 metric   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                 7.114e+04
# Date:                Tue, 29 Oct 2024   Prob (F-statistic):               0.00
# Time:                        14:44:51   Log-Likelihood:                 83.439
# No. Observations:                 500   AIC:                            -162.9
# Df Residuals:                     498   BIC:                            -154.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0041      0.015     -0.285      0.776      -0.033       0.024
# ...

# %%
s = Scenario(scenario_type='diminishing')
s.plot()

# %%
d=Detector()
d.fit(s.data, event_type='diminishing')
d.summary()
d.predict()
d.plot()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 metric   R-squared:                       0.810
# Model:                            OLS   Adj. R-squared:                  0.810
# Method:                 Least Squares   F-statistic:                     2124.
# Date:                Tue, 29 Oct 2024   Prob (F-statistic):          9.25e-182
# Time:                        14:44:58   Log-Likelihood:                 30.435
# No. Observations:                 500   AIC:                            -56.87
# Df Residuals:                     498   BIC:                            -48.44
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# ...

# %%
s = Scenario(scenario_type='constant_with_trend')
s.plot()

# %%
d=Detector()
d.fit(s.data, event_type='constant', detrend=True)
d.summary()
d.predict()
d.plot()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 metric   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                 8.501e+04
# Date:                Tue, 29 Oct 2024   Prob (F-statistic):               0.00
# Time:                        21:11:17   Log-Likelihood:                 88.478
# No. Observations:                 500   AIC:                            -171.0
# Df Residuals:                     497   BIC:                            -158.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0052      0.019     -0.278      0.781      -0.042       0.032
# ...

# %%
s = Scenario(scenario_type='diminishing_with_trend')
s.plot()

# %%
d=Detector()
d.fit(s.data, event_type='diminishing', detrend=True)
d.summary()
d.predict()
d.plot()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 metric   R-squared:                       0.966
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     7162.
# Date:                Tue, 29 Oct 2024   Prob (F-statistic):               0.00
# Time:                        21:14:28   Log-Likelihood:                -74.328
# No. Observations:                 500   AIC:                             154.7
# Df Residuals:                     497   BIC:                             167.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# ...
