# %%
# Libraries
# %load_ext autoreload
# %autoreload 2

import sys; sys.path.insert(0, '..')
from ev_detect.gen_data import Scenario
from ev_detect.evdetector import Detector

# %%
s = Scenario()
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
d.predict()
d.plot()
# Out:
# {'detected': True, 'optimal_results': [{'time': 200, 'coef': 5.14, 'trend': -0.01, 'pval': 0.0, 'trend_pval': 0.06, 'rsquared': 0.99, 'weighted_coef': 5.1, 'detected_event': 1}], 'event_time': np.int64(200), 'event_halflife': inf, 'decay_lambda': np.float64(0.0)}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 4.017e+04
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):               0.00
# Time:                        14:20:27   Log-Likelihood:                 114.62
# No. Observations:                 500   AIC:                            -223.2
# Df Residuals:                     497   BIC:                            -210.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                              0.0075      0.018      0.421      0.674      -0.027       0.042
# event:np.exp(-l * time_from_event)     4.9913      0.033    150.121      0.000       4.926       5.057
# time                                 2.48e-05      0.000      0.220      0.826      -0.000       0.000
# ==============================================================================
# Omnibus:                        0.141   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.932   Jarque-Bera (JB):                0.216
# Skew:                          -0.034   Prob(JB):                        0.898
# Kurtosis:                       2.924   Cond. No.                     1.12e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='diminishing')
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
d.predict()
d.plot()
# Out:
# {'detected': True, 'optimal_results': [{'time': 200, 'coef': 5.72, 'trend': -0.0, 'pval': 0.0, 'trend_pval': 0.76, 'rsquared': 0.94, 'weighted_coef': 5.38, 'detected_event': 1}], 'event_time': np.int64(200), 'event_halflife': np.float64(4.620981203732968), 'decay_lambda': np.float64(0.15000000000000002)}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     1165.
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):          2.60e-188
# Time:                        14:20:58   Log-Likelihood:                 40.107
# No. Observations:                 500   AIC:                            -74.21
# Df Residuals:                     497   BIC:                            -61.57
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             -0.0192      0.020     -0.947      0.344      -0.059       0.021
# event:np.exp(-l * time_from_event)     5.5817      0.116     48.227      0.000       5.354       5.809
# time                                4.095e-05   6.95e-05      0.589      0.556   -9.56e-05       0.000
# ==============================================================================
# Omnibus:                       10.071   Durbin-Watson:                   1.311
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               10.525
# Skew:                          -0.291   Prob(JB):                      0.00518
# Kurtosis:                       3.407   Cond. No.                     3.34e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.34e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='constant_with_trend')
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
d.predict()
d.plot()
# Out:
# {'detected': True, 'optimal_results': [{'time': 200, 'coef': 5.02, 'trend': 0.01, 'pval': 0.0, 'trend_pval': 0.0, 'rsquared': 0.99, 'weighted_coef': 4.99, 'detected_event': 1}], 'event_time': np.int64(200), 'event_halflife': inf, 'decay_lambda': np.float64(0.0)}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                 8.996e+04
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):               0.00
# Time:                        14:21:30   Log-Likelihood:                 102.96
# No. Observations:                 500   AIC:                            -199.9
# Df Residuals:                     497   BIC:                            -187.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                              0.0247      0.018      1.362      0.174      -0.011       0.060
# event:np.exp(-l * time_from_event)     5.0420      0.034    148.151      0.000       4.975       5.109
# time                                   0.0098      0.000     85.169      0.000       0.010       0.010
# ==============================================================================
# Omnibus:                        1.142   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.565   Jarque-Bera (JB):                0.942
# Skew:                           0.060   Prob(JB):                        0.624
# Kurtosis:                       3.176   Cond. No.                     1.12e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='diminishing_with_trend')
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
d.predict()
d.plot()
# Out:
# {'detected': True, 'optimal_results': [{'time': 200, 'coef': 5.5, 'trend': 0.02, 'pval': 0.0, 'trend_pval': 0.0, 'rsquared': 0.92, 'weighted_coef': 5.08, 'detected_event': 1}], 'event_time': np.int64(200), 'event_halflife': np.float64(2.772588722239781), 'decay_lambda': np.float64(0.25)}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.969
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     7667.
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):               0.00
# Time:                        14:22:02   Log-Likelihood:                -47.259
# No. Observations:                 500   AIC:                             100.5
# Df Residuals:                     497   BIC:                             113.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                              0.0757      0.024      3.151      0.002       0.028       0.123
# event:np.exp(-l * time_from_event)     5.9890      0.169     35.472      0.000       5.657       6.321
# time                                   0.0099   8.27e-05    120.015      0.000       0.010       0.010
# ==============================================================================
# Omnibus:                       62.525   Durbin-Watson:                   1.100
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              144.854
# Skew:                           0.666   Prob(JB):                     3.51e-32
# Kurtosis:                       5.276   Cond. No.                     4.09e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.09e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
