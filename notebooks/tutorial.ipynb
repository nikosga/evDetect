# %%
# Libraries
# %load_ext autoreload
# %autoreload 2

import sys; sys.path.insert(0, '..')
from ev_detect.gen_data import Scenario
from ev_detect.evdetector import Detector
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
s = Scenario()
s.plot()

# %%
d=Detector()
d.fit(s.data)
d.summary()
d.predict()
d.plot()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 8.408e+04
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):               0.00
# Time:                        23:13:02   Log-Likelihood:                 123.38
# No. Observations:                 500   AIC:                            -242.8
# Df Residuals:                     498   BIC:                            -234.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0016      0.013     -0.116      0.908      -0.028       0.025
# event          5.0187      0.017    289.968      0.000       4.985       5.053
# ==============================================================================
# Omnibus:                        1.892   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.388   Jarque-Bera (JB):                1.729
# Skew:                          -0.139   Prob(JB):                        0.421
# Kurtosis:                       3.077   Cond. No.                         2.93
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
s = Scenario(scenario_type='diminishing')
s.plot()

# %%
d=Detector()
d.fit(s.data, event_type='diminishing')
d.summary()
d.predict()
d.plot()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.805
# Model:                            OLS   Adj. R-squared:                  0.804
# Method:                 Least Squares   F-statistic:                     2054.
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):          8.19e-179
# Time:                        23:23:39   Log-Likelihood:                -49.165
# No. Observations:                 500   AIC:                             102.3
# Df Residuals:                     498   BIC:                             110.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                              0.0185      0.012      1.520      0.129      -0.005       0.042
# event:np.exp(-l * time_from_event)     5.6955      0.126     45.317      0.000       5.449       5.942
# ==============================================================================
# Omnibus:                       85.556   Durbin-Watson:                   1.076
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              251.612
# Skew:                           0.810   Prob(JB):                     2.31e-55
# Kurtosis:                       6.075   Cond. No.                         10.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
