# %%
# Libraries
# %load_ext autoreload
# %autoreload 2

import sys; sys.path.insert(0, '..')
import time
from evdetect.gen_data import Scenario
from evdetect.evdetector import Detector

# %%
s = Scenario()
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
d.predict()
d.plot()
# Out:
# Estimating on 7 cores
# {'detected': True, 'event_time': 200.0, 'event_halflife': inf, 'decay_lambda': 0.0, 'amplitude': 5.05, 'trend': -0.0, 'rsquared': 0.99}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                 3.514e+04
# Date:                Fri, 01 Nov 2024   Prob (F-statistic):               0.00
# Time:                        16:23:45   Log-Likelihood:                 79.022
# No. Observations:                 500   AIC:                            -152.0
# Df Residuals:                     497   BIC:                            -139.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# event_exp_lt     5.0494      0.036    141.433      0.000       4.979       5.120
# time            -0.0001      0.000     -1.005      0.315      -0.000       0.000
# Intercept       -0.0009      0.019     -0.050      0.960      -0.038       0.036
# ==============================================================================
# Omnibus:                        1.716   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.424   Jarque-Bera (JB):                1.625
# Skew:                           0.055   Prob(JB):                        0.444
# Kurtosis:                       2.743   Cond. No.                     1.12e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='diminishing')
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
d.predict()
d.plot()
# Out:
# Estimating on 7 cores
# {'detected': True, 'event_time': 200.0, 'event_halflife': 4.6, 'decay_lambda': 0.15000000000000002, 'amplitude': 5.63, 'trend': -0.0, 'rsquared': 0.76}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.751
# Model:                            OLS   Adj. R-squared:                  0.750
# Method:                 Least Squares   F-statistic:                     748.5
# Date:                Fri, 01 Nov 2024   Prob (F-statistic):          1.17e-150
# Time:                        16:23:47   Log-Likelihood:                -77.594
# No. Observations:                 500   AIC:                             161.2
# Df Residuals:                     497   BIC:                             173.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# event_exp_lt     5.6483      0.146     38.566      0.000       5.361       5.936
# time         -9.893e-05   8.79e-05     -1.125      0.261      -0.000    7.38e-05
# Intercept        0.0679      0.026      2.654      0.008       0.018       0.118
# ==============================================================================
# Omnibus:                       96.312   Durbin-Watson:                   1.061
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              256.070
# Skew:                           0.946   Prob(JB):                     2.48e-56
# Kurtosis:                       5.951   Cond. No.                     3.34e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.34e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='constant_with_trend')
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
d.predict()
d.plot()
# Out:
# Estimating on 7 cores
# {'detected': True, 'event_time': 200.0, 'event_halflife': inf, 'decay_lambda': 0.0, 'amplitude': 4.99, 'trend': 0.01, 'rsquared': 1.0}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                 8.551e+04
# Date:                Fri, 01 Nov 2024   Prob (F-statistic):               0.00
# Time:                        16:23:50   Log-Likelihood:                 90.158
# No. Observations:                 500   AIC:                            -174.3
# Df Residuals:                     497   BIC:                            -161.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# event_exp_lt     4.9993      0.035    143.184      0.000       4.931       5.068
# time             0.0100      0.000     84.347      0.000       0.010       0.010
# Intercept        0.0015      0.019      0.078      0.938      -0.035       0.038
# ==============================================================================
# Omnibus:                        1.025   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.599   Jarque-Bera (JB):                1.124
# Skew:                          -0.089   Prob(JB):                        0.570
# Kurtosis:                       2.850   Cond. No.                     1.12e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
s = Scenario(scenario_type='diminishing_with_trend')
s.plot()

# %%
d=Detector()
d.fit(s.data)
print(d.summary())
d.predict()
d.plot()
# Out:
# Estimating on 7 cores
# {'detected': True, 'event_time': 200.0, 'event_halflife': 2.0, 'decay_lambda': 0.35000000000000003, 'amplitude': 6.53, 'trend': 0.01, 'rsquared': 0.94}
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 metric   R-squared:                       0.952
# Model:                            OLS   Adj. R-squared:                  0.952
# Method:                 Least Squares   F-statistic:                     4948.
# Date:                Fri, 01 Nov 2024   Prob (F-statistic):               0.00
# Time:                        16:23:53   Log-Likelihood:                -156.31
# No. Observations:                 500   AIC:                             318.6
# Df Residuals:                     497   BIC:                             331.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# event_exp_lt     6.5478      0.237     27.637      0.000       6.082       7.013
# time             0.0099      0.000     96.491      0.000       0.010       0.010
# Intercept        0.0771      0.030      2.586      0.010       0.019       0.136
# ==============================================================================
# Omnibus:                      176.715   Durbin-Watson:                   0.874
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1287.548
# Skew:                           1.343   Prob(JB):                    2.59e-280
# Kurtosis:                      10.388   Cond. No.                     4.62e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.62e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
